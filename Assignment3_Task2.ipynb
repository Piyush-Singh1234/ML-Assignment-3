# %% [markdown]
# # a.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Generate XOR dataset
def generate_xor_data(n_samples):
    X = np.random.rand(n_samples, 2)
    y = np.array([1 if (x[0] > 0.5) != (x[1] > 0.5) else 0 for x in X])
    return X, y

# Create 200 training and 200 test samples
X_train, y_train = generate_xor_data(200)
X_test, y_test = generate_xor_data(200)

# Define the MLP model
model = Sequential([
    Dense(10, input_shape=(2,), activation='relu'),  # Hidden layer with 10 neurons
    Dense(10, activation='relu'),                    # Hidden layer with 10 neurons
    Dense(1, activation='sigmoid')                   # Output layer with 1 neuron
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='test accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy:.2f}")

# Visualize the decision boundary
def plot_decision_boundary(X, y, model):
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o')
    plt.show()

# Plot the decision boundary on training data
plot_decision_boundary(X_train, y_train, model)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.3601 - loss: 0.7007 - val_accuracy: 0.4400 - val_loss: 0.6938
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4550 - loss: 0.6951 - val_accuracy: 0.5700 - val_loss: 0.6899
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6174 - loss: 0.6902 - val_accuracy: 0.6750 - val_loss: 0.6852
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6755 - loss: 0.6852 - val_accuracy: 0.6800 - val_loss: 0.6818
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6511 - loss: 0.6809 - val_accuracy: 0.6650 - val_loss: 0.6796
# Epoch 6/100
# ...

# %% [markdown]
# # b.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.regularizers import l1
import matplotlib.pyplot as plt

# Generate XOR dataset
def generate_xor_data(n_samples):
    X = np.random.rand(n_samples, 2)
    y = np.array([1 if (x[0] > 0.5) != (x[1] > 0.5) else 0 for x in X])
    return X, y

X_train, y_train = generate_xor_data(200)
X_val, y_val = generate_xor_data(100)

# Define the MLP model with L1 regularization
model_l1 = Sequential([
    Dense(10, input_shape=(2,), activation='relu', kernel_regularizer=l1(0.01)),
    Dense(10, activation='relu', kernel_regularizer=l1(0.01)),
    Dense(1, activation='sigmoid')
])

# Compile the model
model_l1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history_l1 = model_l1.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val))

# Plot decision boundary
def plot_decision_boundary(X, y, model):
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o')
    plt.title("Decision Boundary (MLP with L1 Regularization)")
    plt.show()

# Visualize decision boundary for L1 regularized model
plot_decision_boundary(X_train, y_train, model_l1)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - accuracy: 0.3182 - loss: 1.0861 - val_accuracy: 0.3300 - val_loss: 1.0698
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3755 - loss: 1.0756 - val_accuracy: 0.4200 - val_loss: 1.0629
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3685 - loss: 1.0731 - val_accuracy: 0.5100 - val_loss: 1.0561
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4845 - loss: 1.0550 - val_accuracy: 0.5800 - val_loss: 1.0498
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5736 - loss: 1.0512 - val_accuracy: 0.6100 - val_loss: 1.0436
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5936 - loss: 1.0434 - val_accuracy: 0.6100 - val_loss: 1.0373
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5944 - loss: 1.0407 - val_accuracy: 0.6100 - val_loss: 1.0310
# Epoch 8/100
# ...

# %% [markdown]
# # c.

# %%
from tensorflow.keras.regularizers import l2

# Define the MLP model with L2 regularization
model_l2 = Sequential([
    Dense(10, input_shape=(2,), activation='relu', kernel_regularizer=l2(0.01)),
    Dense(10, activation='relu', kernel_regularizer=l2(0.01)),
    Dense(1, activation='sigmoid')
])

# Compile the model
model_l2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history_l2 = model_l2.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val))

# Visualize decision boundary for L2 regularized model
plot_decision_boundary(X_train, y_train, model_l2)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 270ms/step - accuracy: 0.4713 - loss: 0.8550 - val_accuracy: 0.5300 - val_loss: 0.8260
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4853 - loss: 0.8413 - val_accuracy: 0.5400 - val_loss: 0.8188
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5054 - loss: 0.8330 - val_accuracy: 0.5500 - val_loss: 0.8128
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5387 - loss: 0.8227 - val_accuracy: 0.5700 - val_loss: 0.8075
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5827 - loss: 0.8119 - val_accuracy: 0.6400 - val_loss: 0.8028
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5757 - loss: 0.8086 - val_accuracy: 0.6700 - val_loss: 0.7984
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6151 - loss: 0.8028 - val_accuracy: 0.6700 - val_loss: 0.7942
# Epoch 8/100
# ...

# %% [markdown]
# # d.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# Create polynomial features for XOR dataset
poly = PolynomialFeatures(degree=2, include_bias=False)
X_train_poly = poly.fit_transform(X_train)
X_val_poly = poly.transform(X_val)

# Define the logistic regression model with polynomial features
log_reg = LogisticRegression(solver='lbfgs')
log_reg.fit(X_train_poly, y_train)

# Plot decision boundary for Logistic Regression with polynomial features
def plot_decision_boundary_sklearn(X, y, model, poly):
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
    Z = model.predict(poly.transform(np.c_[xx.ravel(), yy.ravel()]))
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o')
    plt.title("Decision Boundary (Logistic Regression with Polynomial Features)")
    plt.show()

# Visualize decision boundary for Logistic Regression
plot_decision_boundary_sklearn(X_train, y_train, log_reg, poly)
